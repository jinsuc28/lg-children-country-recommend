# %%
# 패키지 로드
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 시각화 전역 설정
from matplotlib import rc
import os
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.size"] = 15

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
# 경로 설정
data_path = '../../data'
saved_path = './saved'
output_path = './submission'

# %%
# 데이터 불러오기 
history_df = pd.read_csv(os.path.join(data_path, 'history_data.csv'), encoding='utf-8')
# history_df['profile_id'] = history_df['profile_id'].astype(str)
watch_e_df = pd.read_csv(os.path.join(data_path, 'watch_e_data.csv'), encoding='utf-8')
# watch_e_df['profile_id'] = watch_e_df['profile_id'].astype(str)
buy_df = pd.read_csv(os.path.join(data_path, 'buy_data.csv'), encoding='utf-8')
search_df  = pd.read_csv(os.path.join(data_path, 'search_data.csv'), encoding='utf-8')

meta = pd.read_csv(os.path.join(data_path, 'meta_data.csv'), encoding='utf-8')
meta_p = pd.read_csv(os.path.join(data_path, 'meta_data_plus.csv'), encoding='utf-8')

profile_df = pd.read_csv(os.path.join(data_path, 'profile_data.csv'), encoding='utf-8')

sample_submission = pd.read_csv(os.path.join(data_path, 'sample_submission.csv'), encoding='utf-8')

# %%
pr_interest_keyword_dict = {'P01':'과학기술',
                           'P02':'정서/사회성',
                           'P03':'자연탐구',
                           'P04':'바른생활/안전',
                           'P05':'활동/운동',
                           'P06':'음악예술',
                           'P07':'언어논리',
                           'P08':'수리논리'}
ch_interest_keyword_dict = {'K01':'노래/율동',
                           'K02':'동물/식물',
                           'K03':'동화',
                           'K04':'만들기',
                           'K05':'숫자/계산',
                           'K06':'외국어',
                           'K07':'친구/사람',
                           'K08':'탈것/기계',
                           'K09':'활동/운동'}

pr_list = ['pr_interest_keyword_cd_1','pr_interest_keyword_cd_2','pr_interest_keyword_cd_3']
ch_list = ['ch_interest_keyword_cd_1','ch_interest_keyword_cd_2','ch_interest_keyword_cd_3']
for pr in pr_list:
    profile_df[pr] = profile_df[pr].apply(lambda x: pr_interest_keyword_dict.get(x, np.NaN))
for ch in ch_list:
    profile_df[ch] = profile_df[ch].apply(lambda x: ch_interest_keyword_dict.get(x, np.NaN))

# %%
# 태그 코드는 떨어트릴 거지만 그래도 같이 변경해주자.

meta_p.replace({'keyword_name' : '안데르센상'}, '안데르센',inplace=True)
meta_p.replace({'keyword_name' : '용감함 4'}, '용감함',inplace=True)
meta_p.replace({'keyword_name' : '의사소통'}, '의사소통(Communication)',inplace=True)
meta_p.replace({'keyword_name' : '자신감'}, '자신감(Confidence)',inplace=True)
meta_p.replace({'keyword_name' : '장선혜'}, '장선혜(작화)',inplace=True)
meta_p.replace({'keyword_name' : '최숙희'}, '최숙희(작화)',inplace=True)
meta_p.replace({'keyword_name' : '캐리'}, '캐리TV',inplace=True)

meta_p.replace({'keyword_type' : '05010a01'}, '0501090d',inplace=True)
meta_p.replace({'keyword_type' : '0509071c'}, '05090708',inplace=True)
meta_p.replace({'keyword_type' : '05030908'}, '050c1002',inplace=True)
meta_p.replace({'keyword_type' : '05070607'}, '050c1006',inplace=True)
meta_p.replace({'keyword_type' : '05010907'}, '05010914',inplace=True)
meta_p.replace({'keyword_type' : '05010909'}, '05010915',inplace=True)
meta_p.replace({'keyword_type' : '05080409'}, '0501080a',inplace=True)

# %%
# sub_title 리스트 담기
meta_df_sub_title_list_dict= {}

for idx, row in meta.iterrows():
    if meta_df_sub_title_list_dict.get(row['album_id'], None) == None:
        meta_df_sub_title_list_dict[row['album_id']] = [row['sub_title']]
    elif row['sub_title'] not in meta_df_sub_title_list_dict[row['album_id']]:
        meta_df_sub_title_list_dict[row['album_id']] = meta_df_sub_title_list_dict[row['album_id']]+[row['sub_title']]
        
print('전체 컨텐츠 개수:',len(set(meta.album_id)),'딕셔너리 담긴 아이템 개수:',len(meta_df_sub_title_list_dict))        

meta_df_prepro_sub_title = meta.copy()
meta_df_prepro_sub_title['sub_title'] = meta_df_prepro_sub_title['album_id'].apply(lambda x: meta_df_sub_title_list_dict.get(x, None))

# 전체 중복 삭제하기
meta_df_prepro_sub_title = meta_df_prepro_sub_title.drop_duplicates(subset=['album_id'], ignore_index=True)

print('전체 데이터수와 album_id 개수 동일 확인:', len(meta_df_prepro_sub_title), len(meta_df_prepro_sub_title.album_id.unique()))

# 메타 플러스 데이터 keyword(keyword_name, type)리스트 담기
meta_plus_type_name = meta_p.copy()

type_to_name = {}

for idx, row in meta_p.iterrows():
    type_to_name[row['keyword_type']] = row['keyword_name']
    
meta_plus_type_name['keyword_name'] = meta_plus_type_name['keyword_type'].apply(lambda x: type_to_name[x])    

name_to_type = {}
for idx, row in meta_p.iterrows():
    name_to_type[row['keyword_name']] = row['keyword_type']
    
meta_plus_type_name['keyword_type'] = meta_plus_type_name['keyword_name'].apply(lambda x: name_to_type[x])
# print('keyword_name, keyword_type 개수 확인:',len(set(meta_plus_type_name.keyword_name)), len(set(meta_plus_type_name.keyword_type)))
# print('앨범 당 키워드 중복 여부 확인:',len(meta_p),len(meta_p.drop_duplicates(subset=['album_id','keyword_type'])))

meta_plus_df_prepro_keyword = meta_plus_type_name.copy()

# meta plus data type name 동일하게 만들기

meta_df_keyword_name_list_dict= {}
meta_df_keyword_type_list_dict= {}

for idx, row in meta_plus_df_prepro_keyword.iterrows():
    if meta_df_keyword_name_list_dict.get(row['album_id'], None) == None:
        meta_df_keyword_name_list_dict[row['album_id']] = [row['keyword_name']]
    elif row['keyword_name'] not in meta_df_keyword_name_list_dict[row['album_id']]:
        meta_df_keyword_name_list_dict[row['album_id']] = meta_df_keyword_name_list_dict[row['album_id']]+[row['keyword_name']]

for idx, row in meta_plus_df_prepro_keyword.iterrows():
    if meta_df_keyword_type_list_dict.get(row['album_id'], None) == None:
        meta_df_keyword_type_list_dict[row['album_id']] = [row['keyword_type']]
    elif row['keyword_type'] not in meta_df_keyword_type_list_dict[row['album_id']]:
        meta_df_keyword_type_list_dict[row['album_id']] = meta_df_keyword_type_list_dict[row['album_id']]+[row['keyword_type']]        

meta_plus_df_prepro_keyword['keyword_name'] = meta_plus_df_prepro_keyword['album_id'].apply(lambda x: meta_df_keyword_name_list_dict.get(x, None))
meta_plus_df_prepro_keyword['keyword_type'] = meta_plus_df_prepro_keyword['album_id'].apply(lambda x: meta_df_keyword_type_list_dict.get(x, None))

meta_plus_df_keyword = meta_plus_df_prepro_keyword.drop_duplicates(subset=['album_id'],ignore_index=True).drop(columns=['keyword_value'])

# meta data merge
all_meta_df = pd.merge(meta_df_prepro_sub_title, meta_plus_df_keyword, how='left',on='album_id')
all_meta_df.info()
# Out:
# 전체 컨텐츠 개수: 39875 딕셔너리 담긴 아이템 개수: 39875
# 전체 데이터수와 album_id 개수 동일 확인: 39875 39875
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39875 entries, 0 to 39874
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      39875 non-null  int64
#  1   title         39875 non-null  object
#  2   sub_title     39875 non-null  object
#  3   genre_large   39875 non-null  object
#  4   genre_mid     39875 non-null  object
#  5   genre_small   12279 non-null  object
#  6   country       31773 non-null  object
#  7   run_time      39875 non-null  int64
#  8   onair_date    5208 non-null   float64
#  9   cast_1        26309 non-null  object
#  10  cast_2        21217 non-null  object
#  11  cast_3        15885 non-null  object
#  12  cast_4        11980 non-null  object
#  13  cast_5        6146 non-null   object
#  14  cast_6        2540 non-null   object
#  15  cast_7        743 non-null    object
#  16  keyword_type  39875 non-null  object
#  17  keyword_name  39875 non-null  object
# dtypes: float64(1), int64(2), object(15)
# memory usage: 5.8+ MB

# %%
history_df = history_df.drop_duplicates(subset=['profile_id', 'album_id', 'log_time']).reset_index(drop = True)
history_df = history_df.sort_values(by='log_time')
# print('같은 시간 중복 시청 전처리 전 후:',len(history_meta_profile_df),len(history_meta_profile_duplicate_df))
watch_e_df = watch_e_df.drop_duplicates(subset=['profile_id', 'album_id', 'log_time']).reset_index(drop = True)

# %%
import datetime as dt
history_df['week_day'] = history_df['ss_id'].apply(lambda x: dt.datetime.strptime(str(x)[:8], '%Y%m%d'))
history_df['week'] = history_df['week_day'].apply(lambda x: x.isocalendar()[1])
history_df['day'] = history_df['week_day'].apply(lambda x: x.isocalendar()[2])
history_df = history_df.drop(columns='week_day')

# %%
print('user 수:',len(set(history_df.profile_id)), 'item 수:',len(set(history_df.album_id)))
# Out:
# user 수: 8311 item 수: 20695

# %%
all_meta_df_small = all_meta_df[['album_id','title','sub_title','genre_large','genre_mid','run_time','cast_1','cast_2']]
dataset = pd.merge(history_df, all_meta_df_small, how='left', on='album_id')
drop_columns = ['act_target_dtl','payment','short_trailer','continuous_play']
dataset = dataset.drop(columns=drop_columns)

# %% [markdown]
# # user tracking

# %%
dataset.profile_id.value_counts().describe()
# Out:
# count    8311.000000
# mean      108.200217
# std       261.375965
# min         1.000000
# 25%        10.000000
# 50%        36.000000
# 75%       101.000000
# max      8264.000000
# Name: profile_id, dtype: float64

# %%
# 한 세션의 시청 횟수 ss_cnt 집계해서 넣어주기
ss_cnt = dataset.groupby(['profile_id']).count()['ss_id'].reset_index().rename(columns={'ss_id':'ss_cnt'})
ss_per_cnt = dataset.groupby(['profile_id','ss_id']).count()['log_time'].reset_index().rename(columns={'log_time':'ss_per_cnt'})
dataset= pd.merge(dataset, ss_cnt, how='left', on=['profile_id'])
dataset= pd.merge(dataset, ss_per_cnt, how='left', on=['profile_id','ss_id'])

# %% [markdown]
# - median으로 36회 이상 시청 유저 tracking

# %%
# median
dataset.profile_id.value_counts()[dataset.profile_id.value_counts()==36].head()
# Out:
# 22126    36
# 31272    36
# 12042    36
# 16761    36
# 7957     36
# Name: profile_id, dtype: int64

# %%
# mean
dataset.profile_id.value_counts()[dataset.profile_id.value_counts()==108].head()
# Out:
# 28117    108
# 12603    108
# 9842     108
# 9369     108
# 3035     108
# Name: profile_id, dtype: int64

# %% [markdown]
# # 1. 22126 user tracking(median)

# %%
user_22126 = dataset[dataset['profile_id']==22126]
profile_df[profile_df['profile_id']==22126]
# Out:
#       profile_id sex  age pr_interest_keyword_cd_1 pr_interest_keyword_cd_2  \
# 6032       22126   F    7                     음악예술                     언어논리
#
#      pr_interest_keyword_cd_3 ch_interest_keyword_cd_1  \
# 6032                     수리논리                      만들기
#
#      ch_interest_keyword_cd_2 ch_interest_keyword_cd_3
# 6032                    노래/율동                       동화

# %%
# 총 4번 틈
# 책 앨범만 봄
user_22126
# Out:
#         profile_id           ss_id        log_time  album_id  week  day  \
# 137056       22126  20220309194614  20220309194841      4605    10    3
# 137145       22126  20220309194614  20220309195156      2892    10    3
# 137281       22126  20220309194614  20220309195618      3016    10    3
# 137409       22126  20220309194614  20220309200054      1884    10    3
# 137563       22126  20220309194614  20220309200656      4005    10    3
# 137737       22126  20220309194614  20220309201515      2184    10    3
# 137820       22126  20220309194614  20220309201931      4005    10    3
# 137825       22126  20220309194614  20220309201947      2865    10    3
# 137909       22126  20220309194614  20220309202341      2864    10    3
# 137923       22126  20220309194614  20220309202405      2189    10    3
# 138115       22126  20220309194614  20220309203135      8292    10    3
# 138182       22126  20220309194614  20220309203514      4076    10    3
# 138200       22126  20220309194614  20220309203613       424    10    3
# 138298       22126  20220309194614  20220309204141      2348    10    3
# 213690       22126  20220314144620  20220314144649       424    11    1
# 213749       22126  20220314144620  20220314145215      4076    11    1
# 213750       22126  20220314144620  20220314145237      2348    11    1
# 213781       22126  20220314144620  20220314145649       380    11    1
# 213794       22126  20220314144620  20220314145735      2532    11    1
# 213863       22126  20220314144620  20220314150620      2533    11    1
# 256167       22126  20220317143418  20220317143446      2532    11    4
# 256300       22126  20220317143418  20220317144347       380    11    4
# 256321       22126  20220317143418  20220317144520       424    11    4
# 256398       22126  20220317143418  20220317145104       440    11    4
# 256426       22126  20220317143418  20220317145339      2865    11    4
# 256432       22126  20220317143418  20220317145401      2865    11    4
# 256475       22126  20220317143418  20220317145743      2482    11    4
# 256545       22126  20220317143418  20220317150420       473    11    4
# 256617       22126  20220317143418  20220317151252      2189    11    4
# 256698       22126  20220317143418  20220317152148       949    11    4
# 256731       22126  20220317143418  20220317152429      2192    11    4
# 256769       22126  20220317143418  20220317152833      2867    11    4
# 256796       22126  20220317143418  20220317153104      2533    11    4
# 256814       22126  20220317143418  20220317153317      3817    11    4
# 256820       22126  20220317143418  20220317153345      7067    11    4
# 256894       22126  20220317143418  20220317154012      7633    11    4
#
#                      title                                   sub_title  \
# 137056             어떻게 먹을까                                      [4-5세]
# 137145              모모와 토토                                      [4-5세]
# 137281              커다란 방귀                                      [4-5세]
# 137409             모르는척 공주                                      [4-5세]
# 137563     첫눈을 기다리는 코딱지 코지                                      [4-5세]
# 137737            진정한 일곱 살                                      [6-7세]
# 137820     첫눈을 기다리는 코딱지 코지                                      [4-5세]
# 137825            응가하자, 끙끙                                      [3세이하]
# 137909  과일과 채소로 만든 맛있는 그림책                           [3세이하, [하단]책 지면1]
# 137923              케이크 파티                                      [3세이하]
# 138115          진짜 코파는 이야기                                      [4-5세]
# 138182  반이나 차 있을까 반 밖에 없을까                                      [4-5세]
# 138200            이건 공룡이라고                                      [4-5세]
# 138298            그까짓 주사따위                        [그레이트북스 아이들나라 독점제공!]
# 213690            이건 공룡이라고                                      [4-5세]
# 213749  반이나 차 있을까 반 밖에 없을까                                      [4-5세]
# 213750            그까짓 주사따위                        [그레이트북스 아이들나라 독점제공!]
# 213781           생생한 공룡이야기                                      [3세이하]
# 213794               백조 왕자                                     [키즈스콜레]
# 213863            벌거벗은 임금님                                     [키즈스콜레]
# 256167               백조 왕자                                     [키즈스콜레]
# 256300           생생한 공룡이야기                                      [3세이하]
# 256321            이건 공룡이라고                                      [4-5세]
# 256398           우리 같이 춤출래                                      [4-5세]
# 256426            응가하자, 끙끙                                      [3세이하]
# 256432            응가하자, 끙끙                                      [3세이하]
# 256475            밥 한그릇 뚝딱                                      [3세이하]
# 256545       치카치카 군단과 충치왕국                                      [3세이하]
# 256617              케이크 파티                                      [3세이하]
# 256698               물어보아요                                      [3세이하]
# 256731             두드려 보아요  [3세이하, [아동심리전문가 추천] 인성, 인지 발달에 도움이 되는 그림책]
# 256769               찾아보아요                                      [3세이하]
# 256796            벌거벗은 임금님                                     [키즈스콜레]
# 256814             오즈의 마법사                                     [키즈스콜레]
# 256820                신데렐라                                     [키즈스콜레]
# 256894           장화 신은 고양이                                     [키즈스콜레]
#
#        genre_large genre_mid  run_time cast_1 cast_2  ss_cnt  ss_per_cnt
# 137056          키즈         책       245    NaN    NaN      36          14
# 137145          키즈         책       305    NaN    NaN      36          14
# 137281          키즈         책       346    NaN    NaN      36          14
# 137409          키즈         책       532    NaN    NaN      36          14
# 137563          키즈         책       534    NaN    NaN      36          14
# 137737          키즈         책       269    NaN    NaN      36          14
# 137820          키즈         책       534    NaN    NaN      36          14
# 137825          키즈         책       231    NaN    NaN      36          14
# 137909          키즈         책       233    NaN    NaN      36          14
# 137923          키즈         책       500    NaN    NaN      36          14
# 138115          키즈         책       233    NaN    NaN      36          14
# 138182          키즈         책       265    NaN    NaN      36          14
# 138200          키즈         책       324    NaN    NaN      36          14
# 138298          키즈         책       242    NaN    NaN      36          14
# 213690          키즈         책       324    NaN    NaN      36           6
# 213749          키즈         책       265    NaN    NaN      36           6
# 213750          키즈         책       242    NaN    NaN      36           6
# 213781          키즈         책       147    NaN    NaN      36           6
# 213794          키즈         책       531    NaN    NaN      36           6
# 213863          키즈         책       458    NaN    NaN      36           6
# 256167          키즈         책       531    NaN    NaN      36          16
# 256300          키즈         책       147    NaN    NaN      36          16
# 256321          키즈         책       324    NaN    NaN      36          16
# 256398          키즈         책       442    NaN    NaN      36          16
# 256426          키즈         책       231    NaN    NaN      36          16
# 256432          키즈         책       231    NaN    NaN      36          16
# 256475          키즈         책       426    NaN    NaN      36          16
# 256545          키즈         책       578    NaN    NaN      36          16
# 256617          키즈         책       500    NaN    NaN      36          16
# 256698          키즈         책       198    NaN    NaN      36          16
# 256731          키즈         책       275    NaN    NaN      36          16
# 256769          키즈         책       177    NaN    NaN      36          16
# 256796          키즈         책       458    NaN    NaN      36          16
# 256814          키즈         책       554    NaN    NaN      36          16
# 256820          키즈         책       384    NaN    NaN      36          16
# 256894          키즈         책       373    NaN    NaN      36          16

# %%
user_22126.album_id.value_counts()
# Out:
# 2865    3
# 424     3
# 2348    2
# 4005    2
# 2189    2
# 4076    2
# 380     2
# 2532    2
# 2533    2
# 2482    1
# 7067    1
# 3817    1
# 2867    1
# 2192    1
# 949     1
# 473     1
# 4605    1
# 440     1
# 2892    1
# 8292    1
# 2864    1
# 2184    1
# 1884    1
# 3016    1
# 7633    1
# Name: album_id, dtype: int64

# %% [markdown]
# # 2. user 28117

# %%
user_28117 = dataset[dataset['profile_id']==28117]
profile_df[profile_df['profile_id']==28117]
# Out:
#       profile_id sex  age pr_interest_keyword_cd_1 pr_interest_keyword_cd_2  \
# 7452       28117   M    4                    활동/운동                     자연탐구
#
#      pr_interest_keyword_cd_3 ch_interest_keyword_cd_1  \
# 7452                  바른생활/안전                    동물/식물
#
#      ch_interest_keyword_cd_2 ch_interest_keyword_cd_3
# 7452                    탈것/기계                    노래/율동

# %%
# 앨범번호가 순차적으로 재생이 많이 됨
# 이는 연속 재생시 다음 앨범아이디로 넘어가는 게 아닐까 생각됨
# 6036 ~ 6039
# 7777 ~ 7779
# 3365 ~ 3368

# 수학 컨텐츠길래 부모님이 일정 주기로 틀어주는 건 줄알았더니
# 하루 왠종일 보네 33번을 이건 아이가 좋아서 보는 듯
# 수학 컨텐츠라고 할지라도 아이가 좋아할 수도 있다..
user_28117
# Out:
#         profile_id           ss_id        log_time  album_id  week  day  \
# 598302       28117  20220407211223  20220407211308       125    14    4
# 598517       28117  20220407211223  20220407212152       127    14    4
# 633087       28117  20220409212159  20220409212237       339    14    6
# 633522       28117  20220409212159  20220409213836       124    14    6
# 633699       28117  20220409212159  20220409214502        65    14    6
# 633932       28117  20220409212159  20220409215402       125    14    6
# 634118       28117  20220409212159  20220409220246       127    14    6
# 634250       28117  20220409212159  20220409221008      2029    14    6
# 634402       28117  20220409212159  20220409221750      2029    14    6
# 667062       28117  20220411212003  20220411212039      2052    15    1
# 667090       28117  20220411212003  20220411212151       976    15    1
# 667159       28117  20220411212346  20220411212439      4058    15    1
# 667290       28117  20220411212346  20220411213017      2987    15    1
# 680490       28117  20220412210622  20220412211932      2045    15    2
# 680707       28117  20220412210622  20220412212723       505    15    2
# 680724       28117  20220412210622  20220412212754        51    15    2
# 680871       28117  20220412210622  20220412213419       126    15    2
# 694233       28117  20220413210702  20220413210752       126    15    3
# 694244       28117  20220413210702  20220413210818        16    15    3
# 694333       28117  20220413210702  20220413211451       505    15    3
# 694388       28117  20220413210702  20220413211759      2062    15    3
# 694521                아기 오리 여섯 마리               [리틀베이비범 동물 동요1]          키즈
# 694564             다섯 마리 알록달록 개구리               [리틀베이비범 동물 동요1]          키즈
# 694614              으랏차! 뽀로로 태권댄스               [으랏차! 뽀로로 태권댄스]          키즈
# 694616                        바라밤               [으랏차! 뽀로로 태권댄스]          키즈
# 694623             콩순이 버스 바퀴 데굴데굴                  [콩순이의 율동교실6]          키즈
# 694640                 토글이와 함께 가요             [신기한 한글나라, 책과 놀이]          키즈
# 694661      아기돼지 삼형제 동화속으로: ㅌ ㅍ ㅎ             [신기한 한글나라, 책과 놀이]          키즈
# 694726      아기돼지 삼형제 동화속으로: ㅈ ㅊ ㅋ             [신기한 한글나라, 책과 놀이]          키즈
# 694769      아기돼지 삼형제 동화속으로: ㅂ ㅅ ㅇ             [신기한 한글나라, 책과 놀이]          키즈
# 694816      아기돼지 삼형제 동화속으로: ㄷ ㄹ ㅁ             [신기한 한글나라, 책과 놀이]          키즈
# 694853        아기돼지 삼형제 동화속으로: ㄱ ㄴ             [신기한 한글나라, 책과 놀이]          키즈
# 694909  아기돼지 삼형제 동화속으로: ㅏ ㅗ ㅣ ㅜ ㅓ             [신기한 한글나라, 책과 놀이]          키즈
# 694945     양치기 소년 동화속으로: 받침 ㄱ ㅂ ㅅ             [신기한 한글나라, 책과 놀이]          키즈
# 694991     양치기 소년 동화속으로: 받침 ㄴ ㄹ ㅁ             [신기한 한글나라, 책과 놀이]          키즈
# 695045         양치기 소년 동화속으로: 받침 ㅇ             [신기한 한글나라, 책과 놀이]          키즈
# 695091         양치기 소년 동화속으로: 거어저서             [신기한 한글나라, 책과 놀이]          키즈
# 695134       양치기 소년 동화속으로: 구두수무부우             [신기한 한글나라, 책과 놀이]          키즈
# 695172          양치기 소년 동화속으로: 기~히             [신기한 한글나라, 책과 놀이]          키즈
# 695207        양치기 소년 동화속으로: 고도오코토             [신기한 한글나라, 책과 놀이]          키즈
# 695237         빨간모자 동화속으로: 자차카타파하             [신기한 한글나라, 책과 놀이]          키즈
# 695295          빨간모자 동화속으로: 라마바사아             [신기한 한글나라, 책과 놀이]          키즈
# 695329            빨간모자 동화속으로: 가나다             [신기한 한글나라, 책과 놀이]          키즈
# 695357       빨간모자 동화속으로: 주변 물건 이름             [신기한 한글나라, 책과 놀이]          키즈
# 695400       빨간모자 동화속으로: 채소와 과일이름             [신기한 한글나라, 책과 놀이]          키즈
# 695441           빨간모자 동화속으로: 동물이름             [신기한 한글나라, 책과 놀이]          키즈
# 695473                    이야기 속으로             [신기한 한글나라, 책과 놀이]          키즈
# 695498                할아버지 장갑 이야기           [신기한 한글나라, 자소동화 단계]          키즈
# 695579               곰 세마리네 집 이야기           [신기한 한글나라, 자소동화 단계]          키즈
# 695647                 생강빵 아이 이야기           [신기한 한글나라, 자소동화 단계]          키즈
# 695683                  커다란 무 이야기           [신기한 한글나라, 자소동화 단계]          키즈
# 695803                  커다란 무 이야기           [신기한 한글나라, 자소동화 단계]          키즈
# 695848                  우주에서 온 뿌뿌           [신기한 한글나라, 자소동화 단계]          키즈
# 695884                   나무의 수수께끼           [신기한 한글나라, 자소동화 단계]          키즈
# 695909                 신나는 정글 놀이터           [신기한 한글나라, 자소동화 단계]          키즈
# 695929                   두더지를 웃겨라           [신기한 한글나라, 자소동화 단계]          키즈
# 747634                    티라노사우르스                  [핑크퐁 3D율동동요]          키즈
# 760333                    티라노사우르스                  [핑크퐁 3D율동동요]          키즈
# 760413                두근두근 공룡 박물관                       [키즈스콜레]          키즈
# 760577             100개의 달과 아기 공룡                        [6-7세]          키즈
# 760716                나는 공룡이 될 거야                       [키즈스콜레]          키즈
# 772301                        윙윙윙               [NEW뽀로로와 노래해요2]          키즈
# 772337                  은혜 갚은 두꺼비                        [4-5세]          키즈
# 778134                  어흥! 같이 놀자             [3세이하, 그래그래 언어놀이]          키즈
# 778146                   부릉부릉 자동차             [3세이하, 그래그래 언어놀이]          키즈
# 778156                        주세요             [3세이하, 그래그래 언어놀이]          키즈
# 778176                  나 따라 해 봐요             [3세이하, 그래그래 언어놀이]          키즈
# 778198                    도토리 도토리             [3세이하, 그래그래 언어놀이]          키즈
# 778214                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 778232                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 778250                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 789850                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 789880                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 789901                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 789925                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 789948                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 789965                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 789989                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790023                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 790049                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 790063                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 790079                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 790103                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790131                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 790155                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 790169                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 790186                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 790207                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790228                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 790247                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 790262                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 790273                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 790289                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790311                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 790334                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 790346                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 790361                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 790380                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790404                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
# 790424                   순서대로 찰칵!             [3세이하, 그래그래 수학놀이]          키즈
# 790440                 내 방에 놀러 와!             [3세이하, 그래그래 수학놀이]          키즈
# 790457                   도시락을 냠냠!             [3세이하, 그래그래 수학놀이]          키즈
# 790482                짧게 길게 놀아 볼까             [3세이하, 그래그래 수학놀이]          키즈
# 790503                차례차례 나와라 얍!             [3세이하, 그래그래 수학놀이]          키즈
#
#        genre_mid  run_time    cast_1  cast_2  ss_cnt  ss_per_cnt
# 598302         책       520       NaN     NaN     108           2
# 598517         책       438       NaN     NaN     108           2
# 633087         책       755       NaN     NaN     108           7
# 633522         책       382       NaN     NaN     108           7
# 633699         책       536       NaN     NaN     108           7
# 633932         책       520       NaN     NaN     108           7
# 634118         책       438       NaN     NaN     108           7
# 634250         책       448       NaN     NaN     108           7
# 634402         책       448       NaN     NaN     108           7
# 667062      노래율동        60    엄마 까투리      꽁지     108           2
# 667090      노래율동       106       콩순이      세요     108           2
# 667159         책       334       NaN     NaN     108           2
# 667290         책       349       NaN     NaN     108           2
# 680490         책       468       NaN     NaN     108           4
# 680707         책       603       NaN     NaN     108           4
# 680724         책       381      백설공주    3층가족     108           4
# 680871         책       312       지훈이  쭈르륵 퐁당     108           4
# 694233         책       312       지훈이  쭈르륵 퐁당     108          10
# 694244      노래율동       105       NaN     NaN     108          10
# 694333         책       603       NaN     NaN     108          10
# 694388         책       485       NaN     NaN     108          10
# 694402       외국어        88       NaN     NaN     108          10
# 694432       외국어       117       버스터     NaN     108          10
# 694462      노래율동       135       NaN     NaN     108          10
# 694492      노래율동       124       NaN     NaN     108          10
# 694521      노래율동       113       NaN     NaN     108          10
# 790169      노래율동       133       NaN     NaN     108          33
# 790186      노래율동       157       NaN     NaN     108          33
# 790207      노래율동       185       NaN     NaN     108          33
# 790228      노래율동       140       NaN     NaN     108          33
# 790247      노래율동       135       NaN     NaN     108          33
# 790262      노래율동       133       NaN     NaN     108          33
# 790273      노래율동       157       NaN     NaN     108          33
# 790289      노래율동       185       NaN     NaN     108          33
# 790311      노래율동       140       NaN     NaN     108          33
# 790334      노래율동       135       NaN     NaN     108          33
# 790346      노래율동       133       NaN     NaN     108          33
# 790361      노래율동       157       NaN     NaN     108          33
# 790380      노래율동       185       NaN     NaN     108          33
# 790404      노래율동       140       NaN     NaN     108          33
# 790424      노래율동       135       NaN     NaN     108          33
# 790440      노래율동       133       NaN     NaN     108          33
# 790457      노래율동       157       NaN     NaN     108          33
# 790482      노래율동       185       NaN     NaN     108          33
# 790503      노래율동       140       NaN     NaN     108          33

# %%
# 연속된 앨범일 경우 sub_title 같음 시리즈물인 경우 앨범아이디가 연속되는 경우가 만을 듯
all_meta_df[all_meta_df['album_id'].isin([album_id for album_id in range(6036,6040)])]
all_meta_df[all_meta_df['album_id'].isin([album_id for album_id in range(7777,7780)])]
all_meta_df[all_meta_df['album_id'].isin([album_id for album_id in range(3365,3369)])]
# Out:
#        album_id           title        sub_title genre_large genre_mid  \
# 32263      3365        세 아기 고양이  [리틀베이비범 동물 동요1]          키즈      노래율동
# 32264      3366        다섯 아기 오리  [리틀베이비범 동물 동요1]          키즈      노래율동
# 32265      3367     아기 오리 여섯 마리  [리틀베이비범 동물 동요1]          키즈      노래율동
# 32266      3368  다섯 마리 알록달록 개구리  [리틀베이비범 동물 동요1]          키즈      노래율동
#
#       genre_small country  run_time  onair_date cast_1 cast_2 cast_3 cast_4  \
# 32263          영어      영국       135         NaN    NaN    NaN    NaN    NaN
# 32264          영어      영국       124         NaN    NaN    NaN    NaN    NaN
# 32265          영어      영국       113         NaN    NaN    NaN    NaN    NaN
# 32266          영어      영국       149         NaN    NaN    NaN    NaN    NaN
#
#       cast_5 cast_6 cast_7                                       keyword_type  \
# 32263    NaN    NaN    NaN  [05010401, 05010402, 05010403, 050c0101, 050c0...
# 32264    NaN    NaN    NaN  [05010401, 05010402, 05010407, 05010408, 05090...
# 32265    NaN    NaN    NaN  [05010401, 05010402, 05010407, 05010408, 05090...
# 32266    NaN    NaN    NaN  [05010401, 05010402, 05010403, 05090801, 050c0...
#
#                                             keyword_name
# 32263  [3세, 4세, 5세, 영어유치원, 동식물과 자연, 허락 요청하기, 충고하기, 의복...
# 32264  [3세, 4세, 1세, 2세, 인지, 영어유치원, 동식물과 자연, 취미, 여가활동,...
# 32265  [3세, 4세, 1세, 2세, 협동성, 리더십, 영어유치원, 동식물과 자연, 성격,...
# 32266  [3세, 4세, 5세, 인지, 영어유치원, 동식물과 자연, 색깔, 수량, 동물, 음...

# %%
user_28117.album_id.value_counts().head()
# Out:
# 1738    8
# 2308    7
# 1832    7
# 2221    7
# 1737    7
# Name: album_id, dtype: int64

# %%
# 전부 [3세이하, 그래그래 수학놀이] 타이틀이였음
# 아 그러면 부모님이 학습시키려고 틀어주는 거겠군?
all_meta_df[all_meta_df['album_id'].isin(user_28117.album_id.value_counts().head().index)]
# Out:
#        album_id        title          sub_title genre_large genre_mid  \
# 38680      1737     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동
# 38681      2221   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동
# 38682      1738     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동
# 38683      1832  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동
# 38684      2308  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동
#
#       genre_small country  run_time  onair_date cast_1 cast_2 cast_3 cast_4  \
# 38680         NaN      한국       135         NaN    NaN    NaN    NaN    NaN
# 38681         NaN      한국       133         NaN    NaN    NaN    NaN    NaN
# 38682         NaN      한국       157         NaN    NaN    NaN    NaN    NaN
# 38683         NaN      한국       185         NaN    NaN    NaN    NaN    NaN
# 38684         NaN      한국       140         NaN    NaN    NaN    NaN    NaN
#
#       cast_5 cast_6 cast_7                                       keyword_type  \
# 38680    NaN    NaN    NaN  [05010101, 05010104, 05010202, 05010401, 05010...
# 38681    NaN    NaN    NaN  [05010101, 05010104, 05010202, 05010401, 05010...
# 38682    NaN    NaN    NaN  [05010101, 05010104, 05010202, 05010401, 05010...
# 38683    NaN    NaN    NaN  [05010101, 05010104, 05010202, 05010401, 05010...
# 38684    NaN    NaN    NaN  [05010101, 05010104, 05010202, 05010401, 05010...
#
#                                             keyword_name
# 38680  [시리즈, 책TV, 2분 이상 10분 미만, 3세, 4세, 5세, 엔터, 노래, 음...
# 38681  [시리즈, 책TV, 2분 이상 10분 미만, 3세, 4세, 5세, 엔터, 노래, 음...
# 38682  [시리즈, 책TV, 2분 이상 10분 미만, 3세, 4세, 5세, 엔터, 노래, 음...
# 38683  [시리즈, 책TV, 2분 이상 10분 미만, 3세, 4세, 5세, 엔터, 노래, 음...
# 38684  [시리즈, 책TV, 2분 이상 10분 미만, 3세, 4세, 5세, 엔터, 노래, 음...

# %%
# 수학 컨텐츠길래 부모님이 일정 주기로 틀어주는 건 줄알았더니
# 하루 왠종일 보네 33번을 이건 아이가 좋아서 보는 듯
# 수학 컨텐츠라고 할지라도 아이가 좋아할 수도 있다..
user_28117[user_28117['album_id'].isin(user_28117.album_id.value_counts().head().index)]
# Out:
#         profile_id           ss_id        log_time  album_id  week  day  \
# 778214       28117  20220419153203  20220419154313      1737    16    2
# 778232       28117  20220419153203  20220419154531      2221    16    2
# 778250       28117  20220419153203  20220419154747      1738    16    2
# 789850       28117  20220420132441  20220420132515      1738    16    3
# 789880       28117  20220420132441  20220420132901      1832    16    3
# 789901       28117  20220420132441  20220420133209      2308    16    3
# 789925       28117  20220420132441  20220420133444      1737    16    3
# 789948       28117  20220420132441  20220420133702      2221    16    3
# 789965       28117  20220420132441  20220420133918      1738    16    3
# 789989       28117  20220420132441  20220420134158      1832    16    3
# 790023       28117  20220420132441  20220420134507      2308    16    3
# 790049       28117  20220420132441  20220420134741      1737    16    3
# 790063       28117  20220420132441  20220420134958      2221    16    3
# 790079       28117  20220420132441  20220420135214      1738    16    3
# 790103       28117  20220420132441  20220420135455      1832    16    3
# 790131       28117  20220420132441  20220420135804      2308    16    3
# 790155       28117  20220420132441  20220420140038      1737    16    3
# 790169       28117  20220420132441  20220420140256      2221    16    3
# 790186       28117  20220420132441  20220420140512      1738    16    3
# 790207       28117  20220420132441  20220420140752      1832    16    3
# 790228       28117  20220420132441  20220420141101      2308    16    3
# 790247       28117  20220420132441  20220420141335      1737    16    3
# 790262       28117  20220420132441  20220420141552      2221    16    3
# 790273       28117  20220420132441  20220420141809      1738    16    3
# 790289       28117  20220420132441  20220420142050      1832    16    3
# 790311       28117  20220420132441  20220420142359      2308    16    3
# 790334       28117  20220420132441  20220420142633      1737    16    3
# 790346       28117  20220420132441  20220420142852      2221    16    3
# 790361       28117  20220420132441  20220420143108      1738    16    3
# 790380       28117  20220420132441  20220420143349      1832    16    3
# 790404       28117  20220420132441  20220420143659      2308    16    3
# 790424       28117  20220420132441  20220420143933      1737    16    3
# 790440       28117  20220420132441  20220420144152      2221    16    3
# 790457       28117  20220420132441  20220420144409      1738    16    3
# 790482       28117  20220420132441  20220420144649      1832    16    3
# 790503       28117  20220420132441  20220420144958      2308    16    3
#
#               title          sub_title genre_large genre_mid  run_time cast_1  \
# 778214     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 778232   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 778250     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 789850     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 789880  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 789901  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 789925     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 789948   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 789965     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 789989  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790023  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 790049     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 790063   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 790079     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 790103  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790131  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 790155     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 790169   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 790186     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 790207  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790228  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 790247     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 790262   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 790273     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 790289  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790311  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 790334     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 790346   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 790361     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 790380  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790404  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
# 790424     순서대로 찰칵!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       135    NaN
# 790440   내 방에 놀러 와!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       133    NaN
# 790457     도시락을 냠냠!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       157    NaN
# 790482  짧게 길게 놀아 볼까  [3세이하, 그래그래 수학놀이]          키즈      노래율동       185    NaN
# 790503  차례차례 나와라 얍!  [3세이하, 그래그래 수학놀이]          키즈      노래율동       140    NaN
#
#        cast_2  ss_cnt  ss_per_cnt
# 778214    NaN     108           8
# 778232    NaN     108           8
# 778250    NaN     108           8
# 789850    NaN     108          33
# 789880    NaN     108          33
# 789901    NaN     108          33
# 789925    NaN     108          33
# 789948    NaN     108          33
# 789965    NaN     108          33
# 789989    NaN     108          33
# 790023    NaN     108          33
# 790049    NaN     108          33
# 790063    NaN     108          33
# 790079    NaN     108          33
# 790103    NaN     108          33
# 790131    NaN     108          33
# 790155    NaN     108          33
# 790169    NaN     108          33
# 790186    NaN     108          33
# 790207    NaN     108          33
# 790228    NaN     108          33
# 790247    NaN     108          33
# 790262    NaN     108          33
# 790273    NaN     108          33
# 790289    NaN     108          33
# 790311    NaN     108          33
# 790334    NaN     108          33
# 790346    NaN     108          33
# 790361    NaN     108          33
# 790380    NaN     108          33
# 790404    NaN     108          33
# 790424    NaN     108          33
# 790440    NaN     108          33
# 790457    NaN     108          33
# 790482    NaN     108          33
# 790503    NaN     108          33

# %% [markdown]
# # 3. 12603 user

# %%
user_12603 = dataset[dataset['profile_id']==12603]
profile_df[profile_df['profile_id']==12603]
# Out:
#       profile_id sex  age pr_interest_keyword_cd_1 pr_interest_keyword_cd_2  \
# 3554       12603   F    8                     음악예술                      NaN
#
#      pr_interest_keyword_cd_3 ch_interest_keyword_cd_1  \
# 3554                      NaN                    숫자/계산
# 647082                          안전제일 워밍업 댄스: 비비
# 647112                         안전제일 워밍업 댄스: 아이쿠
# 660319                         목요일은 영어로 어떻게 말하지
# 660324                           캐리와 콜라의 첫 만남 외
# 660333                          오늘은 영어를 배워볼까요 외
# 660344                           콜라도 빨래를 할 거야 외
# 660347                             요구르트 정수기 만들기
# 722736                                 악당이 나타났다
# 722737                          지진, 태풍에서 살아남는 법
# 722742                            상해 콜라 박물관에 가다
# 722744                        엘리와 함께하는 차량 안전 수칙
# 722749                                  펭귄아 뭐하니
# 722750                              겹쳐진 그림을 찾아라
# 722759                                     응가공주
# 722772                                  장수탕 선녀님
# 722778                                  장수탕 선녀님
# 722785                                     응가공주
# 722788                                  장수탕 선녀님
# 724252                                     응가공주
# 724395                                숲으로 간 코끼리
# 724621                               책 읽어주는 고릴라
# 741734             캐리의 프린세스 프링 드레스룸 장난감 인형 놀이 외
# 741778           캐리 엄마와 콩콩이의 공룡알 발굴 키트 장난감 놀이 외
# 741864    캐리와 포비의 두근 두근 점핑 토끼 장난감 당근 뽑기 게임 놀이 외
# 741920             캐리의 똘똘이 아이스크림 가게 장난감 마트 놀이 외
# 741940                 뽀롱뽀롱 뽀로로 그리기 장난감 캐리 그림놀이
# 741964            캐리의 스파클 걸즈 네일 디자인 인형 꾸미기 놀이 외
# 741985           캐리의 내 맘대로 강아지 그리기 인형 장난감 그림 놀이
# 741992     캐리의 휘핑 아트 장난감 아이스크림 케이크 파르페 만들기 놀이 외
# 742014                                  G, H, I
# 776056              캐리의 `네 마음을 말해봐!` 수다펜 장난감 놀이
# 776769              캐리의 `네 마음을 말해봐!` 수다펜 장난감 놀이
# 776842                     캐리의 국기카드 나라이름 맞히기 놀이
# 885751                                    가을홈림픽
# 885761                                 바다의 비밀 5
# 889732                                 악당이 나타났다
# 897228  엔젤이 내가 만들어 먹는 붕어빵과 핫도그 장난감 캐리의 빵 만들기 놀이
#
#                                   sub_title genre_large genre_mid  run_time  \
# 607250                             [마샤와 곰1]          키즈      TV만화       411
# 607315                             [마샤와 곰1]          키즈      TV만화       394
# 607325                             [마샤와 곰1]          키즈      TV만화       376
# 607589               [캐리 앤 하우스 1, 캐리앤 하우스1]          키즈      놀이교실       236
# 607641                               [딩딩코딩]          키즈      창의학습       355
# 607737                              [딩딩코딩2]          키즈      창의학습       373
# 607842                              [딩딩코딩2]          키즈      창의학습       350
# 607950                              [딩딩코딩2]          키즈      창의학습       383
# 608099                              [딩딩코딩2]          키즈      창의학습       375
# 608265                              [딩딩코딩2]          키즈      창의학습       386
# 635591                               [6-7세]          키즈         책       398
# 635601  [6-7세, [아동심리전문가 추천] 따뜻한 이야기를 들려주세요]          키즈         책       531
# 635612  [6-7세, [아동심리전문가 추천] 따뜻한 이야기를 들려주세요]          키즈         책       315
# 635622                               [4-5세]          키즈         책       520
# 635636                               [4-5세]          키즈         책       485
# 635665     [노래율동, 만 4세를 위한 영상, 베이비버스 동물동요1]          키즈     노래 율동       131
# 635669                  [노래율동, 베이비버스 동물동요1]          키즈     노래 율동       133
를 위한 영상, 율동동요 아이쿠]          키즈      노래율동        81
# 647022                           [율동동요 아이쿠]          키즈      노래율동        84
# 647049                           [율동동요 아이쿠]          키즈      노래율동        84
# 647082                           [율동동요 아이쿠]          키즈      노래율동        84
# 647112              [만 5세를 위한 영상, 율동동요 아이쿠]          키즈      노래율동        84
# 660319                    [헬로캐리 Sing Sing1]          키즈      놀이교실       600
# 660324                               [60초툰]          키즈      놀이교실        72
# 660333                               [60초툰]          키즈      놀이교실        64
# 660344                               [60초툰]          키즈      놀이교실        79
# 660347                       [캐빈의 호기심 아파트1]          키즈        예능       577
# 722736               [캐리 앤 하우스 1, 캐리앤 하우스1]          키즈      놀이교실       236
# 722737                           [엘리가 간다26]          키즈      놀이교실       427
# 722742                            [엘리가 간다6]          키즈      놀이교실       797
# 722744                           [엘리가 간다26]          키즈      놀이교실       694
# 722749                         [옥토넛과 노래해요1]          키즈      노래율동       118
# 722750                              [딩딩코딩4]          키즈      창의학습       395
# 722759                               [4-5세]          키즈         책       520
# 722772  [6-7세, [아동심리전문가 추천] 따뜻한 이야기를 들려주세요]          키즈         책       315
# 722778  [6-7세, [아동심리전문가 추천] 따뜻한 이야기를 들려주세요]          키즈         책       315
# 722785                               [4-5세]          키즈         책       520
# 722788  [6-7세, [아동심리전문가 추천] 따뜻한 이야기를 들려주세요]          키즈         책       315
# 724252                               [4-5세]          키즈         책       520
# 724395                               [4-5세]          키즈         책       731
# 724621                               [4-5세]          키즈         책       472
# 741734                          [캐리 앤 토이즈3]          키즈      놀이교실       882
# 741778                          [캐리 앤 토이즈3]          키즈      놀이교실       919
# 741864                          [캐리 앤 토이즈3]          키즈      놀이교실       866
# 741920                          [캐리 앤 토이즈3]          키즈      놀이교실       851
# 741940                          [캐리 앤 토이즈3]          키즈      놀이교실       760
# 741964                          [캐리 앤 토이즈3]          키즈      놀이교실       927
# 741985                          [캐리 앤 토이즈3]          키즈      놀이교실       678
# 741992                          [캐리 앤 토이즈3]          키즈      놀이교실       755
# 742014                           [꼬모와 잉글리시]          키즈      노래율동       419
# 776056                          [캐리 앤 토이즈5]          키즈      놀이교실       825
# 776769                          [캐리 앤 토이즈5]          키즈      놀이교실       825
# 776842                          [캐리 앤 토이즈5]          키즈      놀이교실       754
# 885751                 [부모베스트, 안녕타이니, 흘려듣기]          키즈      육아정보       343
# 885761                      [바다의 비밀, 어린이다큐]          키즈     다큐멘터리       696
# 889732               [캐리 앤 하우스 1, 캐리앤 하우스1]          키즈      놀이교실       236
# 897228                          [캐리 앤 토이즈5]          키즈      놀이교실      1071
#
#          cast_1 cast_2  ss_cnt  ss_per_cnt
# 607250       마샤      곰     108           3
# 607315       마샤      곰     108           3
# 607325       마샤      곰     108           3
# 607589     꼬마캐리   꼬마캐빈     108           7
# 607641       지니     강이     108           7
# 607737       지니     강이     108           7
# 607842       지니     강이     108           7
# 607950       지니     강이     108           7
# 608099       지니     강이     108           7
# 608265       지니     강이     108           7
# 635591      NaN    NaN     108          14
# 635601      NaN    NaN     108          14
# 635612      NaN    NaN     108          14
# 635622      NaN    NaN     108          14
# 635636      NaN    NaN     108          14
# 635665       키키     묘묘     108          14
# 635669       키키     묘묘     108          14
# 635671       키키     묘묘     108          14
# 635674       지니     강이     108          14
# 635682       지니     강이     108          14
# 635692       지니     강이     108          14
# 635706       지니     강이     108          14
# 635722       지니     강이     108          14
